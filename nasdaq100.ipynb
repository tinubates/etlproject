# %%
import requests
import pandas as pd
import bs4
import urllib.parse
import pymongo
import json
import lxml.html
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
from sqlalchemy import create_engine


###### EXTRACT #######

#web-scrape list of stock tickers from nasdaq100
url = 'https://www.nasdaq.com/market-activity/quotes/Nasdaq-100-Index-Components'
response = requests.get(url)
soup = bs4.BeautifulSoup(response.text,'html.parser')
stocks = []
for x in range(100):
    stock = soup.find('td',attrs={'class':'row_{} col_1'.format(x+1)}).a.get('href')
    ticker = stock.replace('/market-activity/stocks/','')
    stocks.append(ticker)
print(stocks)

#get latest stock price from Alpha Vantage API
ts = TimeSeries(key='IPVCAANNDGK60RBH', output_format='pandas')
stockprice=[]
for x in range(5): #due to free API key's limit of 5 calls per minute, we can't loop through all tickers at once
    data, meta_data = ts.get_intraday(symbol=stocks[x],interval='60min', outputsize='full')
    stockprice.append(data.iloc[0][3])
print(stockprice)

#use NewsAPI to get stock news based on ticker found above
stocks_df = pd.DataFrame(stocks)
stocks_df.head()
base_url = 'https://newsapi.org/v2/everything?'
api_key = "apiKey=17454b732308403bac81dfc6f8f2bf48"
mydict = {}
for index, row in stocks_df.head().iterrows():  #create a dictionary
   s_word = (row[0])
   search ='&q=' + str(s_word)
   d_word = '2019-11-11'
   date = '&from' +d_word
   r_json = requests.get("{}{}{}{}".format(base_url,api_key,search,date)).json()
   mydict[s_word] = pd.read_json(json.dumps(r_json['articles'], indent=4))

    
###### TRANSFORM #######

#combine ticker with their corresponding price into a single DF
shorterstocks=stocks[0:5]
tickerprice={'Ticker':shorterstocks,'Price':stockprice}
stockdf = pd.DataFrame(tickerprice)
stockdf
    
AAPL = pd.DataFrame(mydict['AAPL']) #create DF for each stock ticker
AAPL.insert(0, "Ticker", "AAPL")  #insert 'ticker' as the first column
print(AAPL) #sample DF

MSFT = pd.DataFrame(mydict['MSFT'])
MSFT.insert(0, "Ticker", "MSFT")

AMZN = pd.DataFrame(mydict['AMZN'])
AMZN.insert(0, "Ticker", "AMZN")

FB = pd.DataFrame(mydict['FB'])
FB.insert(0, "Ticker", "FB")

GOOG = pd.DataFrame(mydict['GOOG'])
GOOG.insert(0, "Ticker", "GOOG")

final = pd.concat([AAPL, MSFT, AMZN, FB, GOOG]) #Merge all individual stock DF into a single DF
load = pd.merge(stockdf,final,on="Ticker") #Merge stock price with News Info


###### LOAD #######

#CSV version since I fail to install psycopg2 to export to postgres
exportcsv = load.to_csv('etlproject.csv',index=None) 
#if psycopg2 was successfully installed: 
#engine = create_engine('postgresql://postgres:postgres@localhost:5433/etlproject')
#df.to_sql(etlproject, engine)
# Out:
# ['AAPL', 'MSFT', 'AMZN', 'FB', 'GOOG', 'GOOGL', 'INTC', 'CMCSA', 'CSCO', 'PEP', 'ADBE', 'AMGN', 'COST', 'NFLX', 'PYPL', 'NVDA', 'AVGO', 'TXN', 'CHTR', 'QCOM', 'SBUX', 'BKNG', 'GILD', 'CELG', 'MDLZ', 'FISV', 'ADP', 'TMUS', 'INTU', 'ISRG', 'CSX', 'TSLA', 'BIIB', 'MU', 'WBA', 'VRTX', 'AMAT', 'ILMN', 'atvi', 'MAR', 'ROST', 'ADI', 'LRCX', 'KHC', 'NXPI', 'AMD', 'CTSH', 'REGN', 'ORLY', 'ADSK', 'XEL', 'MNST', 'SIRI', 'PAYX', 'EBAY', 'BIDU', 'JD', 'EA', 'CTAS', 'KLAC', 'WDAY', 'PCAR', 'DLTR', 'LULU', 'ALXN', 'WLTW', 'MELI', 'IDXX', 'VRSK', 'UAL', 'XLNX', 'MCHP', 'VRSN', 'CERN', 'FAST', 'NTES', 'ALGN', 'SNPS', 'ASML', 'EXPE', 'CDNS', 'INCY', 'CHKP', 'SWKS', 'CTRP', 'MXIM', 'WDC', 'SYMC', 'CTXS', 'ULTA', 'AAL', 'NTAP', 'WYNN', 'TTWO', 'BMRN', 'JBHT', 'LBTYK', 'HAS', 'FOXA', 'MYL']
# [263.7, 149.455, 1748.62, 195.12, 1330.83]
#    Ticker                                             source  \
# 0    AAPL  {'id': 'business-insider', 'name': 'Business I...
# 1    AAPL  {'id': 'business-insider', 'name': 'Business I...
# 2    AAPL  {'id': 'business-insider', 'name': 'Business I...
# 3    AAPL  {'id': 'business-insider', 'name': 'Business I...
# 4    AAPL  {'id': 'business-insider', 'name': 'Business I...
# 5    AAPL  {'id': 'business-insider', 'name': 'Business I...
# 6    AAPL  {'id': 'business-insider', 'name': 'Business I...
# 7    AAPL  {'id': 'business-insider', 'name': 'Business I...
# 8    AAPL  {'id': 'business-insider', 'name': 'Business I...
# 9    AAPL                {'id': None, 'name': '9to5mac.com'}
# 10   AAPL  {'id': 'business-insider', 'name': 'Business I...
# 11   AAPL  {'id': 'business-insider', 'name': 'Business I...
# 12   AAPL  {'id': 'business-insider', 'name': 'Business I...
# 13   AAPL  {'id': 'business-insider', 'name': 'Business I...
# 14   AAPL  {'id': 'business-insider', 'name': 'Business I...
# 15   AAPL  {'id': 'business-insider', 'name': 'Business I...
# 16   AAPL  {'id': 'business-insider', 'name': 'Business I...
# 17   AAPL  {'id': 'business-insider', 'name': 'Business I...
# 18   AAPL                {'id': None, 'name': '9to5mac.com'}
# 19   AAPL                {'id': None, 'name': '9to5mac.com'}
#
#                  author                                              title  \
# 0        Lisa Eadicicco           LIVE: Here comes Apple's earnings (AAPL)
# 1       Mary Meisenzahl          Apple Music is down for some users (AAPL)
# 2       Mary Meisenzahl  These 3 subtle changes in Apple's latest iPhon...
# 3   Antonio Villas-Boas  Apple is admitting to 2 mistakes with its keyb...
# 4            Dave Smith  Apple and Disney are about to shake up the str...
# 5       Mary Meisenzahl  Apple removed 18 harmful apps from the App Sto...
# 6        Lisa Eadicicco  Apple may release a smaller, cheaper new iPhon...
# 7       Mary Meisenzahl  Teens keep outsmarting Apple's features for li...
# 8        Daniel Strauss  Apple has a new fan on Wall Street — and this ...
# 9           Ben Lovejoy  Analysts expect good but unspectacular results...
# 10     Tyler Sonnemaker  Apple's head of marketing slammed Chromebooks,...
# 11      Mary Meisenzahl  Apple just removed an iPhone app that made it ...
# 12       Lisa Eadicicco  As part of Google, Fitbit could fix one of my ...
# 13       Lisa Eadicicco  There's a strong case being made for why Apple...
# 14       Lisa Eadicicco  Next year’s iPhone is starting to take shape, ...
# 15  Antonio Villas-Boas  It looks like Apple is planning a clever way t...
# 16         Paige Leskin  Twitter CEO Jack Dorsey uses his iPhone's Scre...
# 17          Ben Gilbert  Apple quietly changed the charging case that c...
# 18        Chance Miller  Apple releases fiscal Q4 2019 earnings, announ...
# 19        Chance Miller  Morgan Stanley: Apple TV+ could be $9B busines...
#
#                                           description  \
# 0   Apple will report its quarterly earnings for Q...
# 1   Some users are reporting outages with the Appl...
# 2   Apple released the iOS 13 software update for ...
# 3   Apple released a new 16-inch MacBook Pro that ...
# 4   Apple and Disney are about to launch their hig...
# 5   Apple removed 18 harmful apps from the App Sto...
# 6   Apple is expected to release a new version of ...
# 7   Teens keep discovering ways to get around Appl...
# 8   Apple got a new supporter on Wall Street on We...
# 9   AAPL Q4 earnings are due to be reported on Wed...
# 10  In an interview with CNET, Apple marketing chi...
# 11  Apple removed the app Like Patrol from the App...
# 12  Google is acquiring Fitbit in a $2.1 billion d...
# 13  Some analysts believe acquiring speaker maker ...
# 14  Apple's next-generation iPhones could help the...
# 15  Apple is developing a Tile -like system called...
# 16  Twitter cofounder and CEO Jack Dorsey was inte...
# 17  Apple just unveiled a new version of its wirel...
# 18  AAPL’s Q4 2019 earnings day has arrived. For t...
# 19  In a new investor note today, Morgan Stanley a...
#
#                                                   url  \
# 0   https://www.businessinsider.com/apple-fiscal-q...
# 1   https://www.businessinsider.com/apple-music-ex...
# 2   https://www.businessinsider.com/apple-ios-13-i...
# 3   https://www.businessinsider.com/apple-macbook-...
# 4   https://www.businessinsider.com/apple-disney-t...
# 5   https://www.businessinsider.com/apple-removes-...
# 6   https://www.businessinsider.com/apple-iphone-s...
# 7   https://www.businessinsider.com/apple-screen-t...
# 8   https://www.businessinsider.com/apple-stock-co...
# 9   https://9to5mac.com/2019/10/28/aapl-q4-earning...
# 10  https://www.businessinsider.com/apple-phil-sch...
# 11  https://www.businessinsider.com/apple-removed-...
# 12  https://www.businessinsider.com/google-buying-...
# 13  https://www.businessinsider.com/apple-should-b...
# 14  https://www.businessinsider.com/apple-iphone-1...
# 15  https://www.businessinsider.com/apple-airtags-...
# 16  https://www.businessinsider.com/jack-dorsey-ip...
# 17  https://www.businessinsider.com/apple-airpods-...
# 18  https://9to5mac.com/2019/10/30/aapl-earnings-q...
# 19  https://9to5mac.com/2019/10/23/morgan-stanley-...
#
#                                            urlToImage           publishedAt  \
# 0   https://image.businessinsider.com/5db9c1c4dee0...  2019-10-30T19:15:10Z
# 1   https://image.businessinsider.com/5db74489dee0...  2019-10-28T19:51:56Z
# 2   https://image.businessinsider.com/5dc5af553afd...  2019-11-10T15:04:00Z
# 3   https://image.businessinsider.com/5dcc749a7eec...  2019-11-13T21:28:51Z
# 4   https://image.businessinsider.com/5db85eaedee0...  2019-10-29T15:47:05Z
# 5   https://image.businessinsider.com/5b9e1a3589c8...  2019-10-25T15:30:52Z
# 6   https://image.businessinsider.com/5da4a8304af9...  2019-10-14T17:39:00Z
# 7   https://image.businessinsider.com/5b69c7382be4...  2019-10-15T18:08:33Z
# 8   https://images.markets.businessinsider.com/ima...  2019-11-13T16:43:53Z
# 9   https://9to5mac.com/wp-content/uploads/sites/6...  2019-10-28T11:58:21Z
# 10  https://image.businessinsider.com/5dcc4dd23afd...  2019-11-13T20:57:42Z
# 11  https://image.businessinsider.com/5dc98d4d3afd...  2019-11-11T19:10:54Z
# 12  https://image.businessinsider.com/5dbc9eb6e0ee...  2019-11-02T13:45:00Z
# 13  https://image.businessinsider.com/5dc4305e3afd...  2019-11-07T15:27:04Z
# 14  https://image.businessinsider.com/5db9a778dee0...  2019-10-30T15:55:29Z
# 15  https://image.businessinsider.com/5db9f225dee0...  2019-10-30T21:11:08Z
# 16  https://image.businessinsider.com/5db2f5fadee0...  2019-10-25T14:47:49Z
# 17  https://image.businessinsider.com/5db99829dee0...  2019-10-30T14:20:27Z
# 18  https://9to5mac.com/wp-content/uploads/sites/6...  2019-10-30T20:32:50Z
# 19  https://9to5mac.com/wp-content/uploads/sites/6...  2019-10-24T00:07:53Z
#
#                                               content
# 0   Apple will post its quarterly earnings for the...
# 1   Many users are experiencing outages with Apple...
# 2   Apple released iOS 13 for iPhones in mid-Septe...
# 3   Apple revealed a new 16-inch MacBook Pro on We...
# 4                                                None
# 5   Apple removed 18 apps from the App Store on Fr...
# 6   Apple typically launches its new flagship iPho...
# 7   Kids are outsmarting parents and Silicon Valle...
# 8   Justin Sullivan/Getty Images\r\n<ul><li>Apple ...
# 9   AAPL Q4 earnings are due to be reported on Wed...
# 10  Apple's head of marketing just made a direct d...
# 11  Apple removed the Like Patrol app from the App...
# 12  Google is acquiring popular smartwatch maker F...
# 13  Wall Street has plenty of thoughts about how A...
# 14  Next year could mark a turning point for Apple...
# 15  Apple is reportedly developing a system and de...
# 16  The man in charge of Twitter only spends two h...
# 17  Apple just revealed the first major update to ...
# 18  AAPL’s Q4 2019 earnings day has arrived. For t...
# 19  In a new investor note today, Morgan Stanley a...
